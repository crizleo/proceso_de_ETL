# %%
import pandas as pd

# %%
pd.options.display.max_rows = 10
pd.options.display.max_columns = 10

noticias = pd.read_csv('../eluniversal_2021_01_17_articles.csv')
print(type(noticias))
noticias = noticias[['body','title','link']]
noticias
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                                  body  \
# 0   El problema de seguridad en la plataforma de v...
# 1   La Fundación Cívica Por Cartagena (Funcicar) c...
# 2   Casi siempre ante las dificultades que se nos ...
# 3   Las fuerzas de seguridad de Guatemala continúa...
# 4   En nuestra ciudad tenemos personas que ante la...
# ..                                                ...
# 80  Este jueves 14 de enero se cumplió la primera ...
# 81  Tomó muchos años la gestación del megaproyecto...
# 82  Rondaba los 26 años cuando a mi mentor, Héctor...
# 83  El Gobierno británico anunció este sábado que ...
# 84  Detrás de cada persona hay una historia que co...
#
#                                                 title  \
# 0   Cancillería da por resuelta falla que expuso d...
# 1   Alcaldía solicitó crédito de $80 mil millones ...
# 2                             ¿Qué llevas en tu taza?
# 3   Nueva caravana de migrantes avanza imparable h...
# ...

# %%
#dictionary like
noticias[['title']]
# Out:
#                                                 title
# 0   Cancillería da por resuelta falla que expuso d...
# 1   Alcaldía solicitó crédito de $80 mil millones ...
# 2                             ¿Qué llevas en tu taza?
# 3   Nueva caravana de migrantes avanza imparable h...
# 4                              ¡Vayamos a las raíces!
# ..                                                ...
# 80  Procuraduría definirá el 21 de enero si archiv...
# 81                                     ¿Hidroicuando?
# 82      Una curiosa cita con Alejandro Galvis Ramírez
# 83  El Reino Unido prepara cumbre del G7 presencia...
# 84  En el Real Cartagena volví a nacer: Ignacio Cu...
#
# [85 rows x 1 columns]

# %%
noticias[['title','link']]
# Out:
#                                                 title  \
# 0   Cancillería da por resuelta falla que expuso d...
# 1   Alcaldía solicitó crédito de $80 mil millones ...
# 2                             ¿Qué llevas en tu taza?
# 3   Nueva caravana de migrantes avanza imparable h...
# 4                              ¡Vayamos a las raíces!
# ..                                                ...
# 80  Procuraduría definirá el 21 de enero si archiv...
# 81                                     ¿Hidroicuando?
# 82      Una curiosa cita con Alejandro Galvis Ramírez
# 83  El Reino Unido prepara cumbre del G7 presencia...
# 84  En el Real Cartagena volví a nacer: Ignacio Cu...
#
#                                                  link
# 0   https://www.eluniversal.com.co/colombia/cancil...
# 1   https://www.eluniversal.com.co/politica/alcald...
# 2   https://www.eluniversal.com.co/viernes/que-lle...
# 3   https://www.eluniversal.com.co/mundo/nueva-car...
# ...

# %%
#numpy like
#noticias.iloc[fila_inicio:fila_final , columna_inicio:columna_final]
#no se incluyen los extremos
noticias.iloc[10:15,1:2]
# Out:
#                                                 title
# 10  [Video] Crisis en Brasil por la nueva variante...
# 11  Vendetta dentro de ‘Los Pelusos’ permitió capt...
# 12  Tecnologías emergentes, clave para atender pac...
# 13  Segunda temporada de ‘Selena: la serie’ ya tie...
# 14              Karoll Márquez y los sueños cumplidos

# %%
noticias.iloc[66]['title']
# Out:
# ' EE.UU. “decepcionado” de México por caso de Cienfuegos'

# %%
noticias.iloc[:5, 0:1]
# Out:
#                                                 body
# 0  El problema de seguridad en la plataforma de v...
# 1  La Fundación Cívica Por Cartagena (Funcicar) c...
# 2  Casi siempre ante las dificultades que se nos ...
# 3  Las fuerzas de seguridad de Guatemala continúa...
# 4  En nuestra ciudad tenemos personas que ante la...

# %%
noticias.loc[:,'body':'title']
# Out:
#                                                  body  \
# 0   El problema de seguridad en la plataforma de v...
# 1   La Fundación Cívica Por Cartagena (Funcicar) c...
# 2   Casi siempre ante las dificultades que se nos ...
# 3   Las fuerzas de seguridad de Guatemala continúa...
# 4   En nuestra ciudad tenemos personas que ante la...
# ..                                                ...
# 80  Este jueves 14 de enero se cumplió la primera ...
# 81  Tomó muchos años la gestación del megaproyecto...
# 82  Rondaba los 26 años cuando a mi mentor, Héctor...
# 83  El Gobierno británico anunció este sábado que ...
# 84  Detrás de cada persona hay una historia que co...
#
#                                                 title
# 0   Cancillería da por resuelta falla que expuso d...
# 1   Alcaldía solicitó crédito de $80 mil millones ...
# 2                             ¿Qué llevas en tu taza?
# 3   Nueva caravana de migrantes avanza imparable h...
# ...
